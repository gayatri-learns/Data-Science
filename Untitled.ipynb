# %%
import matplotlib.pyplot as plt

# %%
#Line plot
x = [1,2,3,4]
y = [10,20,45,30]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Simple Line Plot')
plt.show()

# %%
#Pyplot
x = ['Mon','Tue','Wed','Thur','Fri']
y = [10,15,7,20,12]

plt.plot(x,y)
plt.title('Bakery sales this year')

plt.xlabel('Days of the week')
plt.ylabel('Sales per day')
plt.show()

# %%
#Pyplot functions :
'''
plt.xlabel()
plt.ylabel()
plt.plot()
plt.title()
plt.legend()
plt.xticks()
plt.yticks()
plt.xlim()
plt.ylim()
plt.show()
plt.grid()
'''
# Out:
# '\nplt.xlabel()\nplt.ylabel()\nplt.plot()\nplt.title()\nplt.legend()\nplt.xticks()\nplt.yticks()\nplt.xlim()\nplt.ylim()\nplt.show()\nplt.grid()\n'

# %%
months = [1,2,3,4]
sales = [1000,1500,1200,1800]

plt.plot(months,sales,color='blue',linestyle='--',linewidth=2,marker='o',label='2025 sales data')
plt.xlabel('Months')
plt.ylabel('Sales per month')
plt.title('Monthly sales data report')
plt.legend(loc = 'upper left',fontsize = 12) #lower right
plt.grid(color = 'gray',linestyle = ':',linewidth =1)
plt.xlim(1,4)
plt.ylim(0,2000)
plt.xticks([1,2,3,4],['M1','M2','M3','M4'])
plt.show()

# %%
#Bar chart
product = []
